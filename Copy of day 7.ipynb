# %% [markdown]
# Tuples:

# %% [markdown]
# ### tuples are enclosed in paranthesis()
# ### upadation are not possible in tuples

# %% [markdown]
# ##Differences  between lists and tuples
# -

# %%
tuple1(0:3)
# Out:
#   File "<ipython-input-2-41d98cb6b8f5>", line 1
#     tuple1(0:3)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Dictionaries:

# %% [markdown]
# ### Data will been enclosed in 0
# ### the data will be in the form of a key value

# %%
d1={1:"gitam",2:"hyd"}
print(d1)
type(d1)
# Out:
# {1: 'gitam', 2: 'hyd'}
# dict

# %%
dict1={"i","am","from","gitam"}
print(dict1)
# Out:
# {'i', 'gitam', 'from', 'am'}

# %%
d1["mail"]="abc@gmail.com"
d1
# Out:
# {1: 'gitam', 2: 'hyd', 'mail': 'abc@gmail.com'}

# %%
del d1[1]
print(d1)
# Out:
# {2: 'hyd', 'mail': 'abc@gmail.com'}
